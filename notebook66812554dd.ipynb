# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %pip install opencv-python-headless face-recognition numpy pandas ffmpeg-python
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Collecting face-recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting face-recognition-models>=0.3.0 (from face-recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 17.5 MB/s eta 0:00:00:00:010:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from face-recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.10/dist-packages (from face-recognition) (19.24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from face-recognition) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566164 sha256=e2f5b3a213db907a8bdad536a3868667482ae5c040a5fb05ea19a35741b56be7
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, ffmpeg-python, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0 ffmpeg-python-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import face_recognition
import json
import os
from typing import List, Dict


def extract_faces_from_video(video_path: str, reference_image_path: str, output_dir: str):
    os.makedirs(output_dir, exist_ok=True)
    images_dir = os.path.join(output_dir, 'images')
    os.makedirs(images_dir, exist_ok=True)
    video = cv2.VideoCapture(video_path)
    ref_image = face_recognition.load_image_file(reference_image_path)
    ref_encoding = face_recognition.face_encodings(ref_image)[0]
    frame_rate = int(video.get(cv2.CAP_PROP_FPS))
    frame_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    metadata = []
    current_clip_frames = []
    frame_count = 0
    clip_count = 0
    target_face_last_coords = None
    video_writer = None
    success, frame = video.read()
    while success:
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        face_locations = face_recognition.face_locations(rgb_frame)
        face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)
        matched = False
        for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
            matches = face_recognition.compare_faces([ref_encoding], face_encoding, tolerance=0.6)
            if matches[0]:
                matched = True
                target_face_coords = [left, top, right - left, bottom - top]
                current_clip_frames.append({
                    "timestamp": frame_count / frame_rate,
                    "bounding_box": target_face_coords
                })
                cropped_face = frame[top:bottom, left:right]
                face_image_path = os.path.join(images_dir, f"frame_{frame_count}.jpg")
                cv2.imwrite(face_image_path, cropped_face)
                if video_writer is None:
                    clip_path = os.path.join(output_dir, f"clip_{clip_count}.mp4")
                    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
                    video_writer = cv2.VideoWriter(clip_path, fourcc, frame_rate, (frame_width, frame_height))
                video_writer.write(frame)
                if target_face_last_coords and has_scene_changed(target_face_last_coords, target_face_coords):
                    finalize_clip(video_writer, current_clip_frames, clip_count, metadata, output_dir)
                    video_writer = None
                    current_clip_frames = []
                    clip_count += 1
                target_face_last_coords = target_face_coords
        if not matched and video_writer is not None:
            finalize_clip(video_writer, current_clip_frames, clip_count, metadata, output_dir)
            video_writer = None
            current_clip_frames = []
            clip_count += 1
        frame_count += 1
        success, frame = video.read()
    if video_writer is not None:
        finalize_clip(video_writer, current_clip_frames, clip_count, metadata, output_dir)
    metadata_path = os.path.join(output_dir, "metadata.json")
    with open(metadata_path, "w") as f:
        json.dump(metadata, f, indent=4)
    video.release()
    return metadata

def has_scene_changed(last_coords: List[int], current_coords: List[int], threshold: float = 0.5) -> bool:
    x1, y1, w1, h1 = last_coords
    x2, y2, w2, h2 = current_coords
    overlap = max(0, min(x1 + w1, x2 + w2) - max(x1, x2)) * max(0, min(y1 + h1, y2 + h2) - max(y1, y2))
    area1 = w1 * h1
    area2 = w2 * h2
    return (overlap / area1 < threshold) or (overlap / area2 < threshold)

def finalize_clip(video_writer, clip_frames, clip_id, metadata, output_dir):
    video_writer.release()
    clip_path = os.path.join(output_dir, f"clip_{clip_id}.mp4")
    start_time = clip_frames[0]["timestamp"]
    end_time = clip_frames[-1]["timestamp"]
    metadata.append({
        "file_name": os.path.basename(clip_path),
        "start_time": start_time,
        "end_time": end_time,
        "frame_coordinates": [frame["bounding_box"] for frame in clip_frames]
    })
    print(f"Finalized clip: {clip_path} from {start_time} to {end_time}")

# %%
video_file = "/kaggle/input/video-image-recognize/SIDEMEN 100000 MARIO KART RACE.mp4"
reference_image = "/kaggle/input/video-image-recognize/miniminter.jpg"
output_directory = "/kaggle/working"

metadata = extract_faces_from_video(video_file, reference_image, output_directory)
print(f"Processing completed. Metadata saved in {output_directory}/metadata.json")
# Out:
# Finalized clip: /kaggle/working/clip_0.mp4 from 66.33333333333333 to 66.33333333333333
# Finalized clip: /kaggle/working/clip_1.mp4 from 66.43333333333334 to 66.43333333333334
# Finalized clip: /kaggle/working/clip_2.mp4 from 66.73333333333333 to 66.73333333333333
# Finalized clip: /kaggle/working/clip_3.mp4 from 67.63333333333334 to 67.63333333333334
# Finalized clip: /kaggle/working/clip_4.mp4 from 67.7 to 67.76666666666667
# Finalized clip: /kaggle/working/clip_5.mp4 from 68.63333333333334 to 68.63333333333334
# Finalized clip: /kaggle/working/clip_6.mp4 from 69.03333333333333 to 69.03333333333333
# Finalized clip: /kaggle/working/clip_7.mp4 from 69.2 to 69.2
# Finalized clip: /kaggle/working/clip_8.mp4 from 69.36666666666666 to 69.4
# Finalized clip: /kaggle/working/clip_9.mp4 from 69.93333333333334 to 69.96666666666667
# Finalized clip: /kaggle/working/clip_10.mp4 from 70.1 to 70.1
# Finalized clip: /kaggle/working/clip_11.mp4 from 70.23333333333333 to 70.23333333333333
# Finalized clip: /kaggle/working/clip_12.mp4 from 70.3 to 70.33333333333333
# Finalized clip: /kaggle/working/clip_13.mp4 from 70.4 to 70.4
# Finalized clip: /kaggle/working/clip_14.mp4 from 76.43333333333334 to 76.43333333333334
# Finalized clip: /kaggle/working/clip_15.mp4 from 76.46666666666667 to 76.56666666666666
# Finalized clip: /kaggle/working/clip_16.mp4 from 76.96666666666667 to 76.96666666666667
# Finalized clip: /kaggle/working/clip_17.mp4 from 77.0 to 78.26666666666667
# Finalized clip: /kaggle/working/clip_18.mp4 from 78.26666666666667 to 78.26666666666667
# Finalized clip: /kaggle/working/clip_19.mp4 from 78.3 to 78.3
# Finalized clip: /kaggle/working/clip_20.mp4 from 78.3 to 78.3
# Finalized clip: /kaggle/working/clip_21.mp4 from 78.33333333333333 to 78.93333333333334
# Finalized clip: /kaggle/working/clip_22.mp4 from 80.36666666666666 to 80.36666666666666
# Finalized clip: /kaggle/working/clip_23.mp4 from 80.43333333333334 to 80.63333333333334
# Finalized clip: /kaggle/working/clip_24.mp4 from 80.73333333333333 to 80.73333333333333
# Finalized clip: /kaggle/working/clip_25.mp4 from 89.36666666666666 to 89.36666666666666
# Finalized clip: /kaggle/working/clip_26.mp4 from 89.43333333333334 to 89.43333333333334
# Finalized clip: /kaggle/working/clip_27.mp4 from 93.33333333333333 to 93.33333333333333
# Finalized clip: /kaggle/working/clip_28.mp4 from 93.36666666666666 to 94.23333333333333
# Finalized clip: /kaggle/working/clip_29.mp4 from 97.83333333333333 to 97.83333333333333
# Finalized clip: /kaggle/working/clip_30.mp4 from 97.86666666666666 to 99.0
# Finalized clip: /kaggle/working/clip_31.mp4 from 107.46666666666667 to 108.5
# Finalized clip: /kaggle/working/clip_32.mp4 from 122.0 to 122.76666666666667
# Finalized clip: /kaggle/working/clip_33.mp4 from 132.96666666666667 to 132.96666666666667
# Finalized clip: /kaggle/working/clip_34.mp4 from 133.16666666666666 to 133.23333333333332
# Finalized clip: /kaggle/working/clip_35.mp4 from 133.3 to 133.76666666666668
# Finalized clip: /kaggle/working/clip_36.mp4 from 133.83333333333334 to 133.83333333333334
# Finalized clip: /kaggle/working/clip_37.mp4 from 134.03333333333333 to 134.23333333333332
# Finalized clip: /kaggle/working/clip_38.mp4 from 134.3 to 134.3
# Finalized clip: /kaggle/working/clip_39.mp4 from 147.13333333333333 to 147.13333333333333
# Finalized clip: /kaggle/working/clip_40.mp4 from 147.16666666666666 to 147.86666666666667
# Finalized clip: /kaggle/working/clip_41.mp4 from 155.06666666666666 to 156.66666666666666
# Finalized clip: /kaggle/working/clip_42.mp4 from 164.93333333333334 to 165.36666666666667
# Finalized clip: /kaggle/working/clip_43.mp4 from 175.5 to 177.33333333333334
# Finalized clip: /kaggle/working/clip_44.mp4 from 180.26666666666668 to 180.26666666666668
# Finalized clip: /kaggle/working/clip_45.mp4 from 180.3 to 181.06666666666666
# Finalized clip: /kaggle/working/clip_46.mp4 from 181.1 to 181.96666666666667
# Finalized clip: /kaggle/working/clip_47.mp4 from 187.13333333333333 to 187.73333333333332
# Finalized clip: /kaggle/working/clip_48.mp4 from 187.86666666666667 to 187.86666666666667
# Finalized clip: /kaggle/working/clip_49.mp4 from 187.96666666666667 to 187.96666666666667
# Finalized clip: /kaggle/working/clip_50.mp4 from 188.03333333333333 to 188.63333333333333
# Finalized clip: /kaggle/working/clip_51.mp4 from 189.76666666666668 to 189.76666666666668
# Finalized clip: /kaggle/working/clip_52.mp4 from 189.8 to 190.9
# Finalized clip: /kaggle/working/clip_53.mp4 from 196.7 to 196.7
# Finalized clip: /kaggle/working/clip_54.mp4 from 196.73333333333332 to 197.93333333333334
# Finalized clip: /kaggle/working/clip_55.mp4 from 239.66666666666666 to 239.66666666666666
# Finalized clip: /kaggle/working/clip_56.mp4 from 239.7 to 241.9
# Finalized clip: /kaggle/working/clip_57.mp4 from 253.36666666666667 to 254.03333333333333
# Finalized clip: /kaggle/working/clip_58.mp4 from 262.53333333333336 to 264.3333333333333
# Finalized clip: /kaggle/working/clip_59.mp4 from 277.1333333333333 to 279.2
# Finalized clip: /kaggle/working/clip_60.mp4 from 286.93333333333334 to 286.93333333333334
# Finalized clip: /kaggle/working/clip_61.mp4 from 286.96666666666664 to 287.93333333333334
# Finalized clip: /kaggle/working/clip_62.mp4 from 292.5 to 293.43333333333334
# Finalized clip: /kaggle/working/clip_63.mp4 from 332.46666666666664 to 336.06666666666666
# Finalized clip: /kaggle/working/clip_64.mp4 from 341.43333333333334 to 341.43333333333334
# Finalized clip: /kaggle/working/clip_65.mp4 from 341.46666666666664 to 342.93333333333334
# Finalized clip: /kaggle/working/clip_66.mp4 from 364.23333333333335 to 364.23333333333335
# Finalized clip: /kaggle/working/clip_67.mp4 from 364.26666666666665 to 366.06666666666666
# Finalized clip: /kaggle/working/clip_68.mp4 from 369.3666666666667 to 370.6
# Finalized clip: /kaggle/working/clip_69.mp4 from 372.26666666666665 to 372.26666666666665
# Finalized clip: /kaggle/working/clip_70.mp4 from 372.3 to 373.23333333333335
# Finalized clip: /kaggle/working/clip_71.mp4 from 373.3666666666667 to 373.3666666666667
# Finalized clip: /kaggle/working/clip_72.mp4 from 373.46666666666664 to 373.7
# Finalized clip: /kaggle/working/clip_73.mp4 from 410.03333333333336 to 410.03333333333336
# Finalized clip: /kaggle/working/clip_74.mp4 from 410.06666666666666 to 411.43333333333334
# Finalized clip: /kaggle/working/clip_75.mp4 from 411.5 to 411.53333333333336
# Finalized clip: /kaggle/working/clip_76.mp4 from 412.3666666666667 to 412.3666666666667
# Finalized clip: /kaggle/working/clip_77.mp4 from 414.1 to 414.1
# Finalized clip: /kaggle/working/clip_78.mp4 from 414.1333333333333 to 415.8
# Finalized clip: /kaggle/working/clip_79.mp4 from 423.2 to 424.1
# Finalized clip: /kaggle/working/clip_80.mp4 from 427.0 to 427.0
# Finalized clip: /kaggle/working/clip_81.mp4 from 427.03333333333336 to 429.03333333333336
# Finalized clip: /kaggle/working/clip_82.mp4 from 429.06666666666666 to 429.06666666666666
# Finalized clip: /kaggle/working/clip_83.mp4 from 429.1 to 429.96666666666664
# Finalized clip: /kaggle/working/clip_84.mp4 from 433.3666666666667 to 433.3666666666667
# Finalized clip: /kaggle/working/clip_85.mp4 from 433.4 to 435.3
# Finalized clip: /kaggle/working/clip_86.mp4 from 440.03333333333336 to 441.0
# Finalized clip: /kaggle/working/clip_87.mp4 from 464.1333333333333 to 465.6666666666667
# Finalized clip: /kaggle/working/clip_88.mp4 from 481.2 to 482.76666666666665
# Finalized clip: /kaggle/working/clip_89.mp4 from 483.96666666666664 to 488.4
# Finalized clip: /kaggle/working/clip_90.mp4 from 534.0666666666667 to 535.7666666666667
# Finalized clip: /kaggle/working/clip_91.mp4 from 536.0666666666667 to 536.0666666666667
# Finalized clip: /kaggle/working/clip_92.mp4 from 536.1666666666666 to 536.2333333333333
# Finalized clip: /kaggle/working/clip_93.mp4 from 540.0333333333333 to 542.7333333333333
# Finalized clip: /kaggle/working/clip_94.mp4 from 548.6333333333333 to 550.6666666666666
# Finalized clip: /kaggle/working/clip_95.mp4 from 577.6666666666666 to 579.5333333333333
# Finalized clip: /kaggle/working/clip_96.mp4 from 585.5666666666667 to 585.5666666666667
# Finalized clip: /kaggle/working/clip_97.mp4 from 585.6 to 586.1666666666666
# Finalized clip: /kaggle/working/clip_98.mp4 from 586.3666666666667 to 586.3666666666667
# Finalized clip: /kaggle/working/clip_99.mp4 from 586.4 to 586.4
# Finalized clip: /kaggle/working/clip_100.mp4 from 586.5 to 586.5
# Finalized clip: /kaggle/working/clip_101.mp4 from 591.9666666666667 to 591.9666666666667
# Finalized clip: /kaggle/working/clip_102.mp4 from 592.2 to 592.2
# Finalized clip: /kaggle/working/clip_103.mp4 from 592.2333333333333 to 593.9333333333333
# Finalized clip: /kaggle/working/clip_104.mp4 from 596.6666666666666 to 596.6666666666666
# Finalized clip: /kaggle/working/clip_105.mp4 from 601.8333333333334 to 602.4666666666667
# Finalized clip: /kaggle/working/clip_106.mp4 from 602.5333333333333 to 602.5666666666667
# Finalized clip: /kaggle/working/clip_107.mp4 from 603.6666666666666 to 603.6666666666666
# Finalized clip: /kaggle/working/clip_108.mp4 from 603.8666666666667 to 603.8666666666667
# Finalized clip: /kaggle/working/clip_109.mp4 from 604.2666666666667 to 604.2666666666667
# Finalized clip: /kaggle/working/clip_110.mp4 from 604.5 to 604.5
# Finalized clip: /kaggle/working/clip_111.mp4 from 604.5333333333333 to 604.5333333333333
# Finalized clip: /kaggle/working/clip_112.mp4 from 604.6333333333333 to 604.6333333333333
# Finalized clip: /kaggle/working/clip_113.mp4 from 614.0 to 614.0
# Finalized clip: /kaggle/working/clip_114.mp4 from 614.0333333333333 to 614.9666666666667
# Finalized clip: /kaggle/working/clip_115.mp4 from 636.9 to 636.9
# Finalized clip: /kaggle/working/clip_116.mp4 from 636.9333333333333 to 640.4
# Finalized clip: /kaggle/working/clip_117.mp4 from 646.9333333333333 to 646.9333333333333
# Finalized clip: /kaggle/working/clip_118.mp4 from 646.9666666666667 to 649.1666666666666
# Finalized clip: /kaggle/working/clip_119.mp4 from 652.8666666666667 to 652.8666666666667
# Finalized clip: /kaggle/working/clip_120.mp4 from 652.9 to 653.8666666666667
# Finalized clip: /kaggle/working/clip_121.mp4 from 656.8333333333334 to 657.3666666666667
# Finalized clip: /kaggle/working/clip_122.mp4 from 658.4666666666667 to 660.1333333333333
# Finalized clip: /kaggle/working/clip_123.mp4 from 660.5333333333333 to 660.5666666666667
# Finalized clip: /kaggle/working/clip_124.mp4 from 666.2333333333333 to 666.2333333333333
# Finalized clip: /kaggle/working/clip_125.mp4 from 666.2666666666667 to 668.2
# Finalized clip: /kaggle/working/clip_126.mp4 from 670.1333333333333 to 670.1333333333333
# Finalized clip: /kaggle/working/clip_127.mp4 from 670.1666666666666 to 671.4
# Finalized clip: /kaggle/working/clip_128.mp4 from 688.5666666666667 to 688.5666666666667
# Finalized clip: /kaggle/working/clip_129.mp4 from 688.6 to 690.1333333333333
# Finalized clip: /kaggle/working/clip_130.mp4 from 703.5666666666667 to 706.4333333333333
# Finalized clip: /kaggle/working/clip_131.mp4 from 728.6333333333333 to 730.5333333333333
# Finalized clip: /kaggle/working/clip_132.mp4 from 735.5 to 735.5
# Finalized clip: /kaggle/working/clip_133.mp4 from 736.1666666666666 to 736.1666666666666
# Finalized clip: /kaggle/working/clip_134.mp4 from 736.2 to 738.8333333333334
# Finalized clip: /kaggle/working/clip_135.mp4 from 765.2333333333333 to 766.6666666666666
# Finalized clip: /kaggle/working/clip_136.mp4 from 768.6333333333333 to 768.6333333333333
# Finalized clip: /kaggle/working/clip_137.mp4 from 768.6666666666666 to 769.3
# Finalized clip: /kaggle/working/clip_138.mp4 from 782.1 to 782.1
# Finalized clip: /kaggle/working/clip_139.mp4 from 782.1333333333333 to 784.0666666666667
# Finalized clip: /kaggle/working/clip_140.mp4 from 795.4333333333333 to 797.2666666666667
# Finalized clip: /kaggle/working/clip_141.mp4 from 799.8666666666667 to 803.1
# Finalized clip: /kaggle/working/clip_142.mp4 from 804.5333333333333 to 806.2666666666667
# Finalized clip: /kaggle/working/clip_143.mp4 from 806.9666666666667 to 808.1
# Finalized clip: /kaggle/working/clip_144.mp4 from 813.0 to 813.0
# Finalized clip: /kaggle/working/clip_145.mp4 from 813.0333333333333 to 814.6333333333333
# Finalized clip: /kaggle/working/clip_146.mp4 from 816.7333333333333 to 816.7333333333333
# Finalized clip: /kaggle/working/clip_147.mp4 from 816.7666666666667 to 816.8333333333334
# Finalized clip: /kaggle/working/clip_148.mp4 from 834.1666666666666 to 834.1666666666666
# Finalized clip: /kaggle/working/clip_149.mp4 from 834.2 to 836.2666666666667
# Finalized clip: /kaggle/working/clip_150.mp4 from 839.1333333333333 to 840.0
# Finalized clip: /kaggle/working/clip_151.mp4 from 848.4 to 848.4
# Finalized clip: /kaggle/working/clip_152.mp4 from 848.4666666666667 to 848.4666666666667
# Finalized clip: /kaggle/working/clip_153.mp4 from 849.9 to 849.9
# Finalized clip: /kaggle/working/clip_154.mp4 from 853.4666666666667 to 853.4666666666667
# Finalized clip: /kaggle/working/clip_155.mp4 from 853.5 to 856.0333333333333
# Finalized clip: /kaggle/working/clip_156.mp4 from 856.0666666666667 to 856.3666666666667
# Finalized clip: /kaggle/working/clip_157.mp4 from 856.4333333333333 to 856.4333333333333
# Finalized clip: /kaggle/working/clip_158.mp4 from 856.7333333333333 to 856.7333333333333
# Finalized clip: /kaggle/working/clip_159.mp4 from 856.8 to 856.8
# Finalized clip: /kaggle/working/clip_160.mp4 from 856.9333333333333 to 857.0
# Finalized clip: /kaggle/working/clip_161.mp4 from 860.7 to 860.7
# Finalized clip: /kaggle/working/clip_162.mp4 from 860.7333333333333 to 864.1
# Finalized clip: /kaggle/working/clip_163.mp4 from 864.1333333333333 to 864.5666666666667
# Finalized clip: /kaggle/working/clip_164.mp4 from 864.6 to 865.3666666666667
# Finalized clip: /kaggle/working/clip_165.mp4 from 865.4 to 866.1
# Finalized clip: /kaggle/working/clip_166.mp4 from 867.4333333333333 to 867.4333333333333
# Finalized clip: /kaggle/working/clip_167.mp4 from 867.4666666666667 to 869.3666666666667
# Finalized clip: /kaggle/working/clip_168.mp4 from 871.0 to 871.0
# Finalized clip: /kaggle/working/clip_169.mp4 from 871.0333333333333 to 872.7
# Finalized clip: /kaggle/working/clip_170.mp4 from 877.1666666666666 to 878.3
# Finalized clip: /kaggle/working/clip_171.mp4 from 878.3333333333334 to 880.1333333333333
# Finalized clip: /kaggle/working/clip_172.mp4 from 884.6 to 884.6
# Finalized clip: /kaggle/working/clip_173.mp4 from 884.6333333333333 to 885.1333333333333
# Finalized clip: /kaggle/working/clip_174.mp4 from 885.2 to 885.2
# Finalized clip: /kaggle/working/clip_175.mp4 from 888.6666666666666 to 888.6666666666666
# Finalized clip: /kaggle/working/clip_176.mp4 from 888.7333333333333 to 888.7333333333333
# Finalized clip: /kaggle/working/clip_177.mp4 from 894.7 to 894.7
# Finalized clip: /kaggle/working/clip_178.mp4 from 894.7333333333333 to 897.9666666666667
# Finalized clip: /kaggle/working/clip_179.mp4 from 909.3666666666667 to 910.9666666666667
# Finalized clip: /kaggle/working/clip_180.mp4 from 924.4 to 925.6666666666666
# Finalized clip: /kaggle/working/clip_181.mp4 from 939.5 to 940.3
# Finalized clip: /kaggle/working/clip_182.mp4 from 942.5 to 943.5333333333333
# Finalized clip: /kaggle/working/clip_183.mp4 from 958.1 to 960.4333333333333
# Finalized clip: /kaggle/working/clip_184.mp4 from 962.9333333333333 to 964.9666666666667
# Finalized clip: /kaggle/working/clip_185.mp4 from 986.6 to 987.4333333333333
# Finalized clip: /kaggle/working/clip_186.mp4 from 991.6 to 991.6
# Finalized clip: /kaggle/working/clip_187.mp4 from 991.6333333333333 to 991.6666666666666
# Finalized clip: /kaggle/working/clip_188.mp4 from 992.4333333333333 to 992.4333333333333
# Finalized clip: /kaggle/working/clip_189.mp4 from 1011.6666666666666 to 1013.5666666666667
# Finalized clip: /kaggle/working/clip_190.mp4 from 1015.9 to 1019.1666666666666
# Finalized clip: /kaggle/working/clip_191.mp4 from 1032.7333333333333 to 1034.0333333333333
# Finalized clip: /kaggle/working/clip_192.mp4 from 1034.9333333333334 to 1040.9
# Finalized clip: /kaggle/working/clip_193.mp4 from 1048.8666666666666 to 1050.1
# Finalized clip: /kaggle/working/clip_194.mp4 from 1058.8666666666666 to 1060.3
# Finalized clip: /kaggle/working/clip_195.mp4 from 1061.2333333333333 to 1062.2333333333333
# Finalized clip: /kaggle/working/clip_196.mp4 from 1064.1 to 1064.8666666666666
# Finalized clip: /kaggle/working/clip_197.mp4 from 1065.9333333333334 to 1067.4
# Finalized clip: /kaggle/working/clip_198.mp4 from 1068.4666666666667 to 1070.5333333333333
# Finalized clip: /kaggle/working/clip_199.mp4 from 1070.7666666666667 to 1071.3666666666666
# Finalized clip: /kaggle/working/clip_200.mp4 from 1088.4 to 1088.4
# Finalized clip: /kaggle/working/clip_201.mp4 from 1088.4333333333334 to 1089.5666666666666
# Finalized clip: /kaggle/working/clip_202.mp4 from 1092.6333333333334 to 1092.6333333333334
# Finalized clip: /kaggle/working/clip_203.mp4 from 1092.6666666666667 to 1093.6333333333334
# Finalized clip: /kaggle/working/clip_204.mp4 from 1094.6666666666667 to 1094.6666666666667
# Finalized clip: /kaggle/working/clip_205.mp4 from 1094.7 to 1094.7
# Finalized clip: /kaggle/working/clip_206.mp4 from 1094.8666666666666 to 1094.8666666666666
# Finalized clip: /kaggle/working/clip_207.mp4 from 1094.9 to 1095.5
# Finalized clip: /kaggle/working/clip_208.mp4 from 1096.5 to 1096.5
# Finalized clip: /kaggle/working/clip_209.mp4 from 1096.5666666666666 to 1096.6
# Finalized clip: /kaggle/working/clip_210.mp4 from 1097.2666666666667 to 1097.2666666666667
# Finalized clip: /kaggle/working/clip_211.mp4 from 1097.3 to 1097.9333333333334
# Finalized clip: /kaggle/working/clip_212.mp4 from 1098.8 to 1098.8
# Finalized clip: /kaggle/working/clip_213.mp4 from 1098.8666666666666 to 1098.8666666666666
# Finalized clip: /kaggle/working/clip_214.mp4 from 1100.5333333333333 to 1100.5333333333333
# Finalized clip: /kaggle/working/clip_215.mp4 from 1100.5666666666666 to 1101.4666666666667
# Finalized clip: /kaggle/working/clip_216.mp4 from 1114.0 to 1114.0
# Finalized clip: /kaggle/working/clip_217.mp4 from 1114.0333333333333 to 1114.5
# Finalized clip: /kaggle/working/clip_218.mp4 from 1115.4 to 1115.4666666666667
# Finalized clip: /kaggle/working/clip_219.mp4 from 1115.5333333333333 to 1115.6
# Finalized clip: /kaggle/working/clip_220.mp4 from 1115.6666666666667 to 1115.6666666666667
# Finalized clip: /kaggle/working/clip_221.mp4 from 1116.4 to 1116.4
# Finalized clip: /kaggle/working/clip_222.mp4 from 1118.2 to 1118.4
# Finalized clip: /kaggle/working/clip_223.mp4 from 1118.5333333333333 to 1118.5333333333333
# Finalized clip: /kaggle/working/clip_224.mp4 from 1118.6 to 1119.4
# Processing completed. Metadata saved in /kaggle/working/metadata.json

# %%
import os
import zipfile

# Specify the directory containing the files
output_dir = '/kaggle/working'

# Create a ZIP file to store the files
zip_filename = '/kaggle/working/output_files.zip'

# List of file extensions to include in the ZIP file
file_extensions = ['.mp4', '.json']

# Create a ZipFile object for writing
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Walk through the directory
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            # Add .mp4 and .json files to the zip
            if file.endswith(tuple(file_extensions)):
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, output_dir))
    
    # Optionally add directories as well (if needed)
    for dir in dirs:
        dir_path = os.path.join(root, dir)
        zipf.write(dir_path, os.path.relpath(dir_path, output_dir))

print(f"All files have been zipped to {zip_filename}")
# Out:
# All files have been zipped to /kaggle/working/output_files.zip

# %%
import shutil

# Specify the folder you want to zip
folder_path = '/kaggle/working/images'  # Replace with your folder path

# Specify the output zip file path
zip_file_path = '/kaggle/working/images.zip'

# Create a zip file of the folder
shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', folder_path)

print(f"Folder '{folder_path}' has been zipped to '{zip_file_path}'")
# Out:
# Folder '/kaggle/working/images' has been zipped to '/kaggle/working/images.zip'
